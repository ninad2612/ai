# %%
from llama_cpp import Llama

# %%
llm = Llama(
    model_path=r"F:\LLM\Tiny\tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf",  # Replace with the actual path to your GGUF model file
    n_ctx=2048,  # The maximum sequence length to use (adjust as needed)
    n_threads=8,  # The number of CPU threads to use (adjust based on your system)
    n_gpu_layers=35  # The number of layers to offload to GPU (set to 0 if no GPU available)
)
# Out:
# llama_model_loader: loaded meta data with 23 key-value pairs and 201 tensors from F:\LLM\Tiny\tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = tinyllama_tinyllama-1.1b-chat-v1.0
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 5632
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 64
# ...

# %%
prompt = "<|system|>\nYou are a helpful AI assistant.\n<|user|>\nWrite poem on Rain\n<|assistant|>"
output = llm(
    prompt,
    max_tokens=256,  # The maximum number of tokens to generate
    stop=["</s>"],   # The stop token (adjust as needed)
    echo=True        # Whether to echo the prompt in the output
)
print(output)
# Out:
# Llama.generate: prefix-match hit
#
# llama_print_timings:        load time =     874.53 ms
# llama_print_timings:      sample time =      94.23 ms /   165 runs   (    0.57 ms per token,  1750.98 tokens per second)
# llama_print_timings: prompt eval time =     277.43 ms /    11 tokens (   25.22 ms per token,    39.65 tokens per second)
# llama_print_timings:        eval time =   15813.18 ms /   164 runs   (   96.42 ms per token,    10.37 tokens per second)
# llama_print_timings:       total time =   16401.03 ms /   175 tokens
# ...

# %%
from llama_cpp import Llama

llm = Llama(
    model_path=r"F:\LLM\Tiny\tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf",  # Replace with the actual path to your GGUF model file
    n_ctx=2048,  # The maximum sequence length to use (adjust as needed)
    n_threads=8,  # The number of CPU threads to use (adjust based on your system)
    n_gpu_layers=35  # The number of layers to offload to GPU (set to 0 if no GPU available)
)

prompt = "<|system|>\nYou are a helpful AI assistant.\n<|user|>\nWrite poem on Rain\n<|assistant|>"
output = llm(
    prompt,
    max_tokens=256,  # The maximum number of tokens to generate
    stop=["</s>"],   # The stop token (adjust as needed)
    echo=True        # Whether to echo the prompt in the output
)
print(output)

# %%
from langchain_community.llms import LlamaCpp
from langchain_core.callbacks import CallbackManager, StreamingStdOutCallbackHandler
from langchain_core.prompts import PromptTemplate

template = """Question: {question}

Answer: Let's work this out in a step by step way to be sure we have the right answer."""

prompt = PromptTemplate.from_template(template)

# Callbacks support token-wise streaming
callback_manager = CallbackManager([StreamingStdOutCallbackHandler()])

llm = LlamaCpp(
    model_path=r"F:\LLM\Tiny\tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf",
    temperature=0.75,
    max_tokens=2000,
    top_p=1,
    callback_manager=callback_manager,
    verbose=True,  # Verbose is required to pass to the callback manager
)

question = """
Poem on rain
"""
llm.invoke(question)
# Out:
# llama_model_loader: loaded meta data with 23 key-value pairs and 201 tensors from F:\LLM\Tiny\tinyllama-1.1b-chat-v1.0.Q4_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = tinyllama_tinyllama-1.1b-chat-v1.0
# llama_model_loader: - kv   2:                       llama.context_length u32              = 2048
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 2048
# llama_model_loader: - kv   4:                          llama.block_count u32              = 22
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 5632
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 64
# ...

# %%
llm_chain = prompt | llm

# %%
question = input("prompt !!")
llm_chain.invoke({"question": question})
# Out:
# Llama.generate: prefix-match hit
#  Mike Tyson, the retired professional wrestler who was famously known as "Mr. Wrestling" for his incredibly long career and unprecedented feats of strength, has passed away at age 72 after a battle with cancer.
#
# First, let's take a look at the definition of a step:
#
# A step is an element in a process or activity. In this context, the first step would be for Mike Tyson to be born on January 31, 1948. This was his birth date and he would have been born in the year 1948.
#
# Now we can start to work backwards through time with a series of steps:
#
# -1. January 31, 1948, Mike Tyson is born.
# -2. On January 31, 1949, he begins his career in professional wrestling.
# -3. He signs with the American Wrestling Association (AWA) on October 10, 1957, which would have been one year after his birth date of 1948.
# -4. In November 1964, Tyson would be drafted by the United States Army and would leave the wrestling world behind to serve in the Vietnam War.
# ...
